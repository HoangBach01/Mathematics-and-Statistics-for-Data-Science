# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy import stats
from math import *
import sympy as sp

# %%
stats.poisson.pmf(k=0, mu=1.2)
# Out:
# 0.30119421191220214

# %%
1 - stats.expon.cdf(x=2, scale=1/0.6)
# Out:
# 0.3011942119122022

# %%
1 - stats.expon.cdf(x=1, scale=1/1.2)
# Out:
# 0.3011942119122022

# %%
stats.expon.cdf(x=5, scale=1/0.6) - stats.expon.cdf(x=2, scale=1/0.6)
# Out:
# 0.25140714354433824

# %%
stats.poisson.pmf(k=0, mu=0.6*2) * (1 - stats.poisson.pmf(k=0, mu=0.6*3))
# Out:
# 0.2514071435443382

# %%
1 - stats.poisson.pmf(k=0, mu=0.6*2) - stats.poisson.pmf(k=1, mu=0.6*2)
# Out:
# 0.33737273379315524

# %%
1 - stats.poisson.cdf(k=1, mu=0.6*2)
# Out:
# 0.33737273379315535

# %%
data = stats.erlang.rvs(1, scale = 1/0.6, size=1000000)

# %%
sb.distplot(data)

# %%
data.mean()
# Out:
# 1.6653129249800882

# %%
3/0.6
# Out:
# 5.0

# %%
data2 = stats.expon.rvs(scale = 1/0.6, size=1000000)

# %%
sb.distplot(data2)

# %%
data2.mean()
# Out:
# 1.667337519086712

# %%
stats.norm.interval(0.95, loc=175, scale=20/sqrt(40))
# Out:
# (168.8020496769544, 181.1979503230456)

# %%
stats.t.interval(0.95, df=9, loc=240, scale=25/sqrt(10))
# Out:
# (222.1160773511857, 257.8839226488143)
