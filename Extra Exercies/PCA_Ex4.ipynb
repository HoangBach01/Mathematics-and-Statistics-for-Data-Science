# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.decomposition import PCA

# %%
data = pd.read_excel('../Data/B3/Iris.xls')
data
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            iris
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
corr = data.corr()
corr
# Out:
#              sepallength  sepalwidth  petallength  petalwidth
# sepallength     1.000000   -0.109369     0.871754    0.817954
# sepalwidth     -0.109369    1.000000    -0.420516   -0.356544
# petallength     0.871754   -0.420516     1.000000    0.962757
# petalwidth      0.817954   -0.356544     0.962757    1.000000

# %%
sb.heatmap(data=corr, cmap='coolwarm');

# %%
df = data.iloc[:,[0,1,2,3]]
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
pca = PCA(2)
pca.fit(df)
# Out:
# PCA(n_components=2)

# %%
T = pca.transform(df)
transform_data = pd.DataFrame(T, columns=['1st Component', '2nd Component'])

# %%
plt.figure(figsize=(12,10))
sb.scatterplot(data=transform_data, x='1st Component', y='2nd Component', hue=data['iris'], s=80);

# %%
print('Explain percent in total component: '+ str(np.round(np.sum(pca.explained_variance_ratio_)*100,2)) + str('%'))
# Out:
# Explain percent in total component: 97.76%

# %%
u1, s1, v1 = np.linalg.svd(df, full_matrices=False)

# %%
u1.shape
# Out:
# (150, 4)
